# %%
import numpy as np
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from xgboost import plot_importance

from sklearn.metrics import f1_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.utils import class_weight

# %%
df = pd.read_csv("cleaned_data.csv", index_col=0)

df = df[df["CODE_GENDER"] != "XNA"] # filter out gender = XNA bc only 4 entries
categorical = ["NAME_CONTRACT_TYPE", "CODE_GENDER", "FLAG_OWN_CAR", "FLAG_OWN_REALTY"] # change categorical variables to 0, 1 encoding
for col in categorical:
  fst = df[col].iloc[0]
  df[col] = (df[col] == fst).astype(float)

df = df.drop(columns=["OWN_CAR_AGE"]) # drop this because we have the new categorical variables for this info

# %%
# drop entries with a nan
df = df.dropna(axis=0)

# %%
# figure out which columns only have one value
for i in df.columns:
    # if len(pd.unique(df[i])) <= 1:
    print(i, pd.unique(df[i]))
# Out:
# SK_ID_CURR [100002 100003 100004 ... 456253 456254 456255]
# TARGET [1 0]
# NAME_CONTRACT_TYPE [1. 0.]
# CODE_GENDER [1. 0.]
# FLAG_OWN_CAR [1. 0.]
# FLAG_OWN_REALTY [1. 0.]
# CNT_CHILDREN [ 0  1  2  3  4  7  5  6  8  9 11 12 10 19 14]
# AMT_INCOME_TOTAL [202500.  270000.   67500.  ... 936000.   96768.  113062.5]
# AMT_CREDIT [ 406597.5 1293502.5  135000.  ... 1149408.   743863.5 1391130. ]
# AMT_ANNUITY [24700.5 35698.5  6750.  ... 59544.  58770.  77809.5]
# AMT_GOODS_PRICE [ 351000.  1129500.   135000.   513000.   454500.  1395000.  1530000.
#   913500.   652500.    67500.   697500.   247500.   387000.   157500.
#   927000.   450000.   225000.   702000.   270000.   675000.   477000.
#   360000.   180000.   679500.   553500.   540000.   855000.   238500.
#   252000.  1350000.   666000.   202500.   517500.  1588500.  1080000.
#   810000.    90000.   315000.   900000.  1035000.   463500.   459000.
#  1125000.   256500.   585000.   643500.   472500.   337500.   720000.
#   396000.  1089000.   319500.  1435500.   688500.   261000.   468000.
#   198000.   445500.   144000.   166500.   967500.   945000.  1755000.
#  1354500.   306000.   427500.   297000.   148500.   531000.   112500.
#   765000.  2250000.   909000.   630000.  1102500.   405000.   787500.
#   607500.   522000.  1575000.  1215000.   369000.  1305000.   747000.
#   292500.  1201500.   774000.   324000.  1071000.   495000.   333000.
#  1138500.  1800000.  1143000.  1008000.  1237500.   414000.   904500.
#    81000.  1039500.   103500.   877500.   562500.   139500.   346500.
#   693000.  1345500.   328500.   634500.   832500.   783000.   922500.
#   117000.   382500.   936000.   130500.  1012500.   508500.  1183500.
#  1053000.   778500.   441000.   391500.   526500.   400500.   760500.
#   283500.   670500.   279000.   828000.  1219500.   409500.   490500.
#   657000.    45000.   229500.   805500.  1017000.   265500.   963000.
#   792000.   603000.  1098000.  1377000.   549000.   288000.  1327500.
#  1282500.   558000.    94500.   972000.   990000.   184500.  1323000.
#   481500.  1260000.   436500.   576000.  1210500.   544500.  1003500.
#   193500.  1984500.   886500.   567000.   958500.   859500.   684000.
#  1165500.   432000.   931500.   171000.   153000.  1467000.   729000.
#  1057500.   211500.   583569.   616500.   342000.   742500.   243000.
#   810022.5  644962.5  410274.   858762.   205533.  1058976.   537700.5
#   466083.   552384.   969241.5  383035.5  137142.  1836000.   778801.5
#   872739.   638302.5 2385000.  1039315.5  233928.   620424.   478917.
#   314946.   891418.5  607603.5  141354.   584995.5  942201.   559836.
#   113724.  2155500.  1305706.5  503559.   718110.   346099.5 2520000.
#   458028.  1948500.   917365.5  556794.   178344.   473845.5  851769.
#  3060000.  2061000.   780597.   955003.5  997281.   159066.  1805922.
#   285844.5  635008.5  742540.5   40500.   607608.   991476.   258624.
#   314968.5  448731.   384772.5 1259671.5  766444.5  264600.   453465.
#   743863.5]
# REGION_POPULATION_RELATIVE [0.018801 0.003541 0.010032 0.028663 0.035792 0.003122 0.018634 0.0228
#  0.015221 0.031329 0.016612 0.020713 0.04622  0.025164 0.006296 0.026392
#  0.018029 0.019101 0.008575 0.01885  0.030755 0.006207 0.009175 0.007305
#  0.010966 0.019689 0.022625 0.01452  0.006629 0.010006 0.00733  0.032561
#  0.00496  0.072508 0.009657 0.02461  0.003069 0.008019 0.018209 0.020246
#  0.009549 0.007274 0.010276 0.003813 0.003818 0.00712  0.0105   0.010147
#  0.010643 0.008866 0.00702  0.002506 0.009334 0.007114 0.005313 0.006233
#  0.008474 0.005144 0.011657 0.008625 0.014464 0.00963  0.006008 0.005002
#  0.006852 0.011703 0.006305 0.010556 0.00823  0.006671 0.002042 0.005084
#  0.008068 0.004849 0.001333 0.001417 0.001276 0.002134 0.000938 0.000533
#  0.00029 ]
# DAYS_BIRTH [ -9461 -16765 -19046 ...  -7857 -25061 -24918]
# DAYS_EMPLOYED [  -637  -1188   -225 ... -11084  -7499  -8694]
# DAYS_REGISTRATION [ -3648.  -1186.  -4260. ... -16396. -15953. -14558.]
# DAYS_ID_PUBLISH [-2120  -291 -2531 ... -5906 -5854 -6211]
# FLAG_MOBIL [1]
# FLAG_EMP_PHONE [1 0]
# FLAG_WORK_PHONE [0 1]
# FLAG_CONT_MOBILE [1 0]
# FLAG_PHONE [1 0]
# FLAG_EMAIL [0 1]
# CNT_FAM_MEMBERS [ 1.  2.  3.  4.  5.  6.  9.  7.  8. 10. 13. 14. 12. 20. 15. 16. 11.]
# REGION_RATING_CLIENT [2 1 3]
# REGION_RATING_CLIENT_W_CITY [2 1 3]
# HOUR_APPR_PROCESS_START [10 11  9 16 14 15  7 13  6 12  8 19  3 17 18 21  4  5 20 22  1  2 23  0]
# REG_REGION_NOT_LIVE_REGION [0 1]
# REG_REGION_NOT_WORK_REGION [0 1]
# LIVE_REGION_NOT_WORK_REGION [0 1]
# REG_CITY_NOT_LIVE_CITY [0 1]
# REG_CITY_NOT_WORK_CITY [0 1]
# LIVE_CITY_NOT_WORK_CITY [0 1]
# OBS_30_CNT_SOCIAL_CIRCLE [  2.   1.   0.   8.  10.   4.   7.   3.   6.   5.  13.  12.  11.  14.
#    9.  22.  16.  15.  17.  20.  25.  19.  18.  21.  24.  23.  28.  26.
#   29.  27.  47. 348.  30.]
# DEF_30_CNT_SOCIAL_CIRCLE [ 2.  0.  1.  3.  5.  4.  6.  7. 34.  8.]
# OBS_60_CNT_SOCIAL_CIRCLE [  2.   1.   0.   8.  10.   4.   7.   3.   6.   5.  13.  12.  11.  14.
#    9.  21.  15.  22.  16.  20.  25.  17.  19.  18.  24.  23.  28.  29.
#   27.  47. 344.  30.  26.]
# DEF_60_CNT_SOCIAL_CIRCLE [ 2.  0.  1.  3.  5.  4.  7. 24.  6.]
# DAYS_LAST_PHONE_CHANGE [-1134.  -828.  -815. ... -3899. -3559. -3538.]
# AMT_REQ_CREDIT_BUREAU_HOUR [0. 1. 2. 3. 4.]
# AMT_REQ_CREDIT_BUREAU_DAY [0. 1. 3. 2. 4. 5. 6. 9. 8.]
# AMT_REQ_CREDIT_BUREAU_WEEK [0. 1. 3. 2. 4. 5. 6. 8. 7.]
# AMT_REQ_CREDIT_BUREAU_MON [ 0.  1.  2.  6.  5.  3.  7.  9.  4. 11.  8. 16. 12. 14. 10. 13. 17. 24.
#  19. 15. 23. 18. 27. 22.]
# AMT_REQ_CREDIT_BUREAU_QRT [  0.   1.   2.   4.   3.   8.   5.   6.   7. 261.  19.]
# AMT_REQ_CREDIT_BUREAU_YEAR [ 1.  0.  2.  4.  5.  3.  8.  6.  9.  7. 10. 11. 13. 16. 12. 25. 23. 15.
#  14. 22. 17. 19. 18. 21. 20.]
# car_owned_less_10 [False  True]
# car_owned_10_to_20 [False  True]
# car_owned_20_to_30 [False  True]
# car_owned_30 [False  True]
# no_car [ True False]
# Children [0 1]
# Family [0 1]
# Group of people [0 1]
# Other_A [0 1]
# Other_B [0 1]
# Spouse, partner [0 1]
# Unaccompanied [1 0]
# Businessman [0 1]
# Commercial associate [0 1]
# Maternity leave [0 1]
# Pensioner [0 1]
# State servant [0 1]
# Student [0 1]
# Unemployed [0 1]
# Working [1 0]
# Academic degree [0 1]
# Higher education [0 1]
# Incomplete higher [0 1]
# Lower secondary [0 1]
# Secondary / secondary special [1 0]
# Civil marriage [0 1]
# Married [0 1]
# Separated [0 1]
# Single / not married [1 0]
# Unknown [0]
# Widow [0 1]
# Co-op apartment [0 1]
# House / apartment [1 0]
# Municipal apartment [0 1]
# Office apartment [0 1]
# Rented apartment [0 1]
# With parents [0 1]
# Accountants [0 1]
# Cleaning staff [0 1]
# Cooking staff [0 1]
# Core staff [0 1]
# Drivers [0 1]
# HR staff [0 1]
# High skill tech staff [0 1]
# IT staff [0 1]
# Laborers [1 0]
# Low-skill Laborers [0 1]
# Managers [0 1]
# Medicine staff [0 1]
# Private service staff [0 1]
# Realty agents [0 1]
# Sales staff [0 1]
# Secretaries [0 1]
# Security staff [0 1]
# Waiters/barmen staff [0 1]
# FRIDAY [0 1]
# MONDAY [0 1]
# SATURDAY [0 1]
# SUNDAY [0 1]
# THURSDAY [0 1]
# TUESDAY [0 1]
# WEDNESDAY [1 0]
# Advertising [0 1]
# Agriculture [0 1]
# Bank [0 1]
# Business Entity Type 1 [0 1]
# Business Entity Type 2 [0 1]
# Business Entity Type 3 [1 0]
# Cleaning [0 1]
# Construction [0 1]
# Culture [0 1]
# Electricity [0 1]
# Emergency [0 1]
# Government [0 1]
# Hotel [0 1]
# Housing [0 1]
# Industry: type 1 [0 1]
# Industry: type 10 [0 1]
# Industry: type 11 [0 1]
# Industry: type 12 [0 1]
# Industry: type 13 [0 1]
# Industry: type 2 [0 1]
# Industry: type 3 [0 1]
# Industry: type 4 [0 1]
# Industry: type 5 [0 1]
# Industry: type 6 [0 1]
# Industry: type 7 [0 1]
# Industry: type 8 [0 1]
# Industry: type 9 [0 1]
# Insurance [0 1]
# Kindergarten [0 1]
# Legal Services [0 1]
# Medicine [0 1]
# Military [0 1]
# Mobile [0 1]
# Other [0 1]
# Police [0 1]
# Postal [0 1]
# Realtor [0 1]
# Religion [0 1]
# Restaurant [0 1]
# School [0 1]
# Security [0 1]
# Security Ministries [0 1]
# Self-employed [0 1]
# Services [0 1]
# Telecom [0 1]
# Trade: type 1 [0 1]
# Trade: type 2 [0 1]
# Trade: type 3 [0 1]
# Trade: type 4 [0 1]
# Trade: type 5 [0 1]
# Trade: type 6 [0 1]
# Trade: type 7 [0 1]
# Transport: type 1 [0 1]
# Transport: type 2 [0 1]
# Transport: type 3 [0 1]
# Transport: type 4 [0 1]
# University [0 1]
# XNA [0 1]

# %%
df['car_owned_less_10'] = df['car_owned_less_10'].astype(float)
df['car_owned_10_to_20'] = df['car_owned_10_to_20'].astype(float)
df['car_owned_20_to_30'] = df['car_owned_20_to_30'].astype(float)
df['car_owned_30'] = df['car_owned_30'].astype(float)
df['no_car'] = df['no_car'].astype(float)

# %%
df = df.drop(columns=["FLAG_MOBIL", "Unknown"]) #these columns now only have one value so they are useless for predicting --> remove them

# %%
#pd.value_counts(df["TARGET"])
not ((df["TARGET"] < 0) & (df["TARGET"] > 1)).any()
# Out:
# True

# %%
cols = ['no_car', 'Group of people', 'CNT_CHILDREN', 'Maternity leave', 'Widow', 'Co-op apartment', 'IT staff', 'SUNDAY', 'Industry: type 8', 'Academic degree']
df_tmp = df.drop(cols, axis=1)
# df_tmp['constant'] = np.ones(df.shape[0])
# print(np.linalg.matrix_rank(df_tmp))
# for i in df_tmp.columns:
#     # if len(pd.unique(df[i])) <= 1:
#     x_tmp = df_tmp.drop([i], axis=1)
#     print(i, np.linalg.matrix_rank(x_tmp))

# %%
# logistic regression
Xtrain = df_tmp.drop(columns=["TARGET", "SK_ID_CURR"], axis=1)
Xtrain = sm.add_constant(Xtrain, prepend=False)
ytrain = df_tmp["TARGET"]

log_reg = sm.Logit(ytrain, Xtrain.astype(float)).fit()

print(log_reg.summary())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.256978
#          Iterations: 35
# c:\Users\Benja\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 TARGET   No. Observations:               264894
# Model:                          Logit   Df Residuals:                   264744
# Method:                           MLE   Df Model:                          149
# Date:                Sun, 30 Apr 2023   Pseudo R-squ.:                 0.05610
# Time:                        21:04:46   Log-Likelihood:                -68072.
# converged:                      False   LL-Null:                       -72118.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# NAME_CONTRACT_TYPE                0.3562      0.033     10.930      0.000       0.292       0.420
# CODE_GENDER                       0.3082      0.019     15.818      0.000       0.270       0.346
# FLAG_OWN_CAR                     14.2105   1864.732      0.008      0.994   -3640.598    3669.019
# FLAG_OWN_REALTY                   0.0250      0.017      1.487      0.137      -0.008       0.058
# AMT_INCOME_TOTAL               2.167e-07   8.78e-08      2.469      0.014    4.47e-08    3.89e-07
# AMT_CREDIT                     2.735e-06    1.2e-07     22.782      0.000     2.5e-06    2.97e-06
# AMT_ANNUITY                     8.16e-06   9.02e-07      9.042      0.000    6.39e-06    9.93e-06
# AMT_GOODS_PRICE               -3.386e-06   1.37e-07    -24.637      0.000   -3.66e-06   -3.12e-06
# REGION_POPULATION_RELATIVE        0.4807      0.688      0.699      0.485      -0.867       1.829
# DAYS_BIRTH                     3.961e-05   2.64e-06     14.980      0.000    3.44e-05    4.48e-05
# DAYS_EMPLOYED                  8.367e-05    4.7e-06     17.797      0.000    7.45e-05    9.29e-05
# DAYS_REGISTRATION              1.578e-05   2.39e-06      6.608      0.000    1.11e-05    2.05e-05
# DAYS_ID_PUBLISH                7.282e-05   5.22e-06     13.957      0.000    6.26e-05     8.3e-05
# FLAG_EMP_PHONE                   -0.9922      1.087     -0.913      0.361      -3.123       1.139
# FLAG_WORK_PHONE                   0.2420      0.020     12.243      0.000       0.203       0.281
# FLAG_CONT_MOBILE                 -0.3343      0.174     -1.919      0.055      -0.676       0.007
# FLAG_PHONE                       -0.0794      0.018     -4.342      0.000      -0.115      -0.044
# FLAG_EMAIL                       -0.0155      0.032     -0.481      0.630      -0.079       0.048
# CNT_FAM_MEMBERS                   0.0052      0.011      0.481      0.631      -0.016       0.026
# REGION_RATING_CLIENT             -0.0063      0.051     -0.124      0.902      -0.106       0.094
# REGION_RATING_CLIENT_W_CITY       0.3695      0.051      7.208      0.000       0.269       0.470
# HOUR_APPR_PROCESS_START          -0.0065      0.002     -2.722      0.006      -0.011      -0.002
# REG_REGION_NOT_LIVE_REGION       -0.3066      0.109     -2.818      0.005      -0.520      -0.093
# REG_REGION_NOT_WORK_REGION        0.1793      0.115      1.555      0.120      -0.047       0.405
# LIVE_REGION_NOT_WORK_REGION      -0.2353      0.115     -2.054      0.040      -0.460      -0.011
# REG_CITY_NOT_LIVE_CITY            0.2234      0.038      5.815      0.000       0.148       0.299
# REG_CITY_NOT_WORK_CITY           -0.0213      0.043     -0.500      0.617      -0.105       0.062
# LIVE_CITY_NOT_WORK_CITY           0.0978      0.042      2.357      0.018       0.016       0.179
# OBS_30_CNT_SOCIAL_CIRCLE          0.0260      0.055      0.475      0.635      -0.081       0.133
# DEF_30_CNT_SOCIAL_CIRCLE          0.1539      0.030      5.085      0.000       0.095       0.213
# OBS_60_CNT_SOCIAL_CIRCLE         -0.0280      0.055     -0.506      0.613      -0.136       0.080
# DEF_60_CNT_SOCIAL_CIRCLE          0.0564      0.036      1.568      0.117      -0.014       0.127
# DAYS_LAST_PHONE_CHANGE            0.0002   9.89e-06     17.922      0.000       0.000       0.000
# AMT_REQ_CREDIT_BUREAU_HOUR       -0
# Industry: type 4                  0.4987      1.044      0.478      0.633      -1.547       2.545
# Industry: type 5                  0.2795      1.051      0.266      0.790      -1.780       2.339
# Industry: type 6                  0.3644      1.110      0.328      0.743      -1.811       2.540
# Industry: type 7                  0.4698      1.042      0.451      0.652      -1.573       2.513
# Industry: type 9                  0.2039      1.039      0.196      0.844      -1.833       2.241
# Insurance                         0.3529      1.056      0.334      0.738      -1.716       2.422
# Kindergarten                      0.4965      1.038      0.478      0.632      -1.538       2.531
# Legal Services                    0.8621      1.066      0.809      0.419      -1.227       2.951
# Medicine                          0.4621      1.038      0.445      0.656      -1.572       2.496
# Military                          0.0652      1.041      0.063      0.950      -1.975       2.106
# Mobile                            0.6162      1.058      0.582      0.560      -1.458       2.690
# Other                             0.4594      1.037      0.443      0.658      -1.573       2.492
# Police                            0.1232      1.042      0.118      0.906      -1.919       2.166
# Postal                            0.6383      1.040      0.614      0.539      -1.400       2.677
# Realtor                           1.0542      1.054      1.000      0.317      -1.011       3.120
# Religion                          0.5379      1.138      0.472      0.637      -1.694       2.769
# Restaurant                        0.6828      1.040      0.657      0.511      -1.355       2.721
# School                            0.3831      1.038      0.369      0.712      -1.651       2.417
# Security                          0.4135      1.039      0.398      0.691      -1.624       2.451
# Security Ministries               0.0941      1.043      0.090      0.928      -1.950       2.138
# Self-employed                     0.6002      1.037      0.579      0.563      -1.432       2.632
# Services                          0.3561      1.043      0.341      0.733      -1.689       2.401
# Telecom                           0.5535      1.051      0.527      0.599      -1.507       2.614
# Trade: type 1                     0.3319      1.060      0.313      0.754      -1.745       2.409
# Trade: type 2                     0.0681      1.042      0.065      0.948      -1.974       2.110
# Trade: type 3                     0.5939      1.038      0.572      0.567      -1.442       2.629
# Trade: type 4                    -0.3098      1.265     -0.245      0.807      -2.789       2.169
# Trade: type 5                     0.0409      1.268      0.032      0.974      -2.445       2.527
# Trade: type 6                     0.0392      1.058      0.037      0.970      -2.034       2.112
# Trade: type 7                     0.5376      1.038      0.518      0.604      -1.496       2.571
# Transport: type 1                -0.1558      1.099     -0.142      0.887      -2.309       1.998
# Transport: type 2                 0.3913      1.040      0.376      0.707      -1.647       2.430
# Transport: type 3                 0.9679      1.041      0.930      0.352      -1.072       3.008
# Transport: type 4                 0.5034      1.038      0.485      0.628      -1.531       2.537
# University                        0.3356      1.046      0.321      0.748      -1.714       2.385
# XNA                             -15.5066   5197.500     -0.003      0.998   -1.02e+04    1.02e+04
# const                           -25.4738   1884.717     -0.014      0.989   -3719.451    3668.503
# =================================================================================================

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(class_weight='balanced', max_iter=10000)

Xtrain = df_tmp.drop(columns=["TARGET", "SK_ID_CURR"], axis=1)
# Xtrain = sm.add_constant(Xtrain, prepend=False)
ytrain = df_tmp["TARGET"]

logreg.fit(Xtrain, ytrain)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=10000)

# %%
#logreg.score(Xtrain, ytrain)
f1 = f1_score(ytrain, logreg.predict(Xtrain))
f1
# Out:
# 0.175071737717393

# %%
print(classification_report(ytrain, logreg.predict(Xtrain)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.61      0.74    244404
#            1       0.10      0.54      0.18     20490
#
#     accuracy                           0.61    264894
#    macro avg       0.52      0.58      0.46    264894
# weighted avg       0.88      0.61      0.70    264894

# %%
# linear model 
x = sm.add_constant(Xtrain, prepend=False)
mod = sm.OLS(ytrain, x.astype(float))
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 TARGET   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     54.32
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):               0.00
# Time:                        23:34:08   Log-Likelihood:                -22180.
# No. Observations:              264894   AIC:                         4.466e+04
# Df Residuals:                  264742   BIC:                         4.626e+04
# Df Model:                         151
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# NAME_CONTRACT_TYPE                0.0203      0.002     10.434      0.000       0.016       0.024
# CODE_GENDER                       0.0235      0.001     17.230      0.000       0.021       0.026
# FLAG_OWN_CAR                      0.0899      0.118      0.762      0.446      -0.141       0.321
# FLAG_OWN_REALTY                   0.0016      0.001      1.362      0.173      -0.001       0.004
# CNT_CHILDREN                     -0.0073      0.017     -0.433      0.665      -0.040       0.026
# AMT_INCOME_TOTAL               8.729e-09   2.12e-09      4.125      0.000    4.58e-09    1.29e-08
# AMT_CREDIT                     1.791e-07   8.22e-09     21.793      0.000    1.63e-07    1.95e-07
# AMT_ANNUITY                    5.849e-07   5.92e-08      9.886      0.000    4.69e-07    7.01e-07
# AMT_GOODS_PRICE               -2.181e-07   9.06e-09    -24.078      0.000   -2.36e-07      -2e-07
# REGION_POPULATION_RELATIVE        0.1361      0.045      3.045      0.002       0.049       0.224
# DAYS_BIRTH                     3.079e-06   1.88e-07     16.419      0.000    2.71e-06    3.45e-06
# DAYS_EMPLOYED                  4.274e-06    2.7e-07     15.833      0.000    3.75e-06     4.8e-06
# DAYS_REGISTRATION              9.599e-07   1.57e-07      6.119      0.000    6.52e-07    1.27e-06
# DAYS_ID_PUBLISH                 5.27e-06   3.65e-07     14.449      0.000    4.55e-06    5.98e-06
# FLAG_EMP_PHONE                   -0.0690      0.089     -0.776      0.438      -0.243       0.105
# FLAG_WORK_PHONE                   0.0170      0.001     11.848      0.000       0.014       0.020
# FLAG_CONT_MOBILE                 -0.0195      0.012     -1.684      0.092      -0.042       0.003
# FLAG_PHONE                       -0.0045      0.001     -3.748      0.000      -0.007      -0.002
# FLAG_EMAIL                       -0.0011      0.002     -0.497      0.619      -0.005       0.003
# CNT_FAM_MEMBERS                   0.0071      0.017      0.425      0.671      -0.026       0.040
# REGION_RATING_CLIENT              0.0004      0.003      0.111      0.912      -0.006       0.007
# REGION_RATING_CLIENT_W_CITY       0.0264      0.003      7.889      0.000       0.020       0.033
# HOUR_APPR_PROCESS_START          -0.0005      0.000     -3.028      0.002      -0.001      -0.000
# REG_REGION_NOT_LIVE_REGION       -0.0208      0.007     -3.130      0.002      -0.034      -0.008
# REG_REGION_NOT_WORK_REGION        0.0085      0.007      1.194      0.232      -0.005       0.023
# LIVE_REGION_NOT_WORK_REGION      -0.0116      0.007     -1.623      0.105      -0.026       0.002
# Trade: type 7                     0.0366      0.005      7.264      0.000       0.027       0.047
# Transport: type 1                -0.0050      0.020     -0.254      0.799      -0.043       0.033
# Transport: type 2                 0.0257      0.007      3.662      0.000       0.012       0.039
# Transport: type 3                 0.0825      0.009      8.904      0.000       0.064       0.101
# Transport: type 4                 0.0336      0.005      6.199      0.000       0.023       0.044
# University                        0.0285      0.009      3.333      0.001       0.012       0.045
# XNA                              -1.5883      0.160     -9.923      0.000      -1.902      -1.275
# const                             0.0170      0.038      0.445      0.657      -0.058       0.092
# ==============================================================================
# Omnibus:                   158847.437   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1031252.498
# Skew:                           3.023   Prob(JB):                         0.00
# Kurtosis:                      10.542   Cond. No.                     1.20e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.83e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
X = Xtrain
y = ytrain
seed = 100
test_size = 0.25

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)
classes_weights = class_weight.compute_sample_weight(
    class_weight='balanced',
    y=y_train
)

# xgb_classifier.fit(X, y, sample_weight=classes_weights)


model = XGBClassifier(base_score=np.sum(y_train == 0)/len(y_train), max_depth=10)
model.fit(X_train, y_train, sample_weight=classes_weights)
# Out:
# XGBClassifier(base_score=0.9222982835858459, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_train, model.predict(X_train))
print("Train Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Train Accuracy: 90.06%

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Test Accuracy: 80.65%

# %%
feat_dict= {}
for col, val in sorted(zip(X_train.columns, model.feature_importances_),key=lambda x:x[1],reverse=True):
  feat_dict[col]=val
feat_df = pd.DataFrame({'Feature':feat_dict.keys(),'Importance':feat_dict.values()})
feat_df
# Out:
#                          Feature  Importance
# 0               Higher education    0.052926
# 1              car_owned_less_10    0.025108
# 2    REGION_RATING_CLIENT_W_CITY    0.020899
# 3                    CODE_GENDER    0.019918
# 4             NAME_CONTRACT_TYPE    0.015859
# ..                           ...         ...
# 144                    Pensioner    0.000000
# 145                   Unemployed    0.000000
# 146            Industry: type 13    0.000000
# 147             Industry: type 6    0.000000
# 148                          XNA    0.000000
#
# [149 rows x 2 columns]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.85      0.89     61171
#            1       0.15      0.31      0.20      5053
#
#     accuracy                           0.81     66224
#    macro avg       0.54      0.58      0.54     66224
# weighted avg       0.88      0.81      0.84     66224

# %%
f1_score(y_train, model.predict(X_train), sample_weight=classes_weights)
# Out:
# 0.9369179784775752

# %%
classes_weights_test = class_weight.compute_sample_weight(
    class_weight='balanced',
    y=y_test
)
f1 = f1_score(y_test, y_pred, sample_weight=classes_weights_test)
f1
# Out:
# 0.42801593279823114

# %%
y_pred_adjusted = []
for pred in model.predict_proba(X_test):
    if pred[1] >= 0.1:
        y_pred_adjusted.append(1)
    else:
        y_pred_adjusted.append(0)
print(classification_report(y_test, y_pred_adjusted))
f1_2 = f1_score(y_test, y_pred_adjusted)
print(f1_2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.31      0.47     61171
#            1       0.09      0.84      0.16      5053
#
#     accuracy                           0.35     66224
#    macro avg       0.53      0.57      0.32     66224
# weighted avg       0.89      0.35      0.45     66224
#
# 0.16464740602671638

# %%
model.best_iteration
# Out:
# 99

# %%
df_tmp.to_csv('clean2_data.csv')
